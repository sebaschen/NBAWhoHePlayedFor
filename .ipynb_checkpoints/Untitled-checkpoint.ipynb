# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
print('==NBA, where amazing happens==')
data = pd.read_csv('data/nba_lottery_picks_data.csv',nrows=1000)
data = data.drop(columns=['Unnamed: 0'],axis=1)
# Out:
# ==NBA, where amazing happens==

# %%
data.head(14)
# Out:
#     pick_overall  Year team_id              player     college_name  seasons  \
# 0              1  1995     GSW           Joe Smith         Maryland     16.0
# 1              2  1995     LAC     Antonio McDyess          Alabama     15.0
# 2              3  1995     PHI    Jerry Stackhouse              UNC     18.0
# 3              4  1995     WSB     Rasheed Wallace              UNC     16.0
# 4              5  1995     MIN       Kevin Garnett              NaN     21.0
# 5              6  1995     VAN       Bryant Reeves   Oklahoma State      6.0
# 6              7  1995     TOR    Damon Stoudamire          Arizona     13.0
# 7              8  1995     POR       Shawn Respert   Michigan State      4.0
# 8              9  1995     NJN         Ed O'Bannon             UCLA      2.0
# 9             10  1995     MIA         Kurt Thomas              TCU     18.0
# 10            11  1995     MIL          Gary Trent  Ohio University      9.0
# 11            12  1995     DAL      Cherokee Parks             Duke      9.0
# 12            13  1995     SAC  Corliss Williamson         Arkansas     12.0
# 13            14  1995     BOS       Eric Williams       Providence     12.0
#
#          g       mp      pts      trb  ...  fg3_pct  ft_pct  mp_per_g  \
# 0   1030.0  27022.0  11208.0   6575.0  ...    0.238   0.790      26.2
# 1   1015.0  28053.0  12227.0   7638.0  ...    0.117   0.670      27.6
# 2    970.0  30222.0  16409.0   3067.0  ...    0.309   0.822      31.2
# 3   1109.0  36243.0  16006.0   7404.0  ...    0.336   0.721      32.7
# 4   1462.0  50418.0  26071.0  14662.0  ...    0.275   0.789      34.5
# 5    395.0  12071.0   4945.0   2745.0  ...    0.074   0.703      30.6
# 6    878.0  29106.0  11763.0   3039.0  ...    0.357   0.833      33.2
# 7    172.0   2350.0    851.0    226.0  ...    0.340   0.816      13.7
# 8    128.0   2062.0    634.0    316.0  ...    0.222   0.755      16.1
# 9   1110.0  27160.0   8973.0   7328.0  ...    0.281   0.760      24.5
# 10   506.0   9866.0   4366.0   2276.0  ...    0.080   0.643      19.5
# 11   472.0   7459.0   2056.0   1703.0  ...    0.211   0.630      15.8
# 12   822.0  18749.0   9147.0   3183.0  ...    0.136   0.714      22.8
# 13   658.0  15731.0   5642.0   2139.0  ...    0.318   0.736      23.9
#
#     pts_per_g  trb_per_g  ast_per_g     ws  ws_per_48  bpm  vorp
# 0        10.9        6.4        1.0   60.3      0.107 -1.5   3.0
# 1        12.0        7.5        1.3   69.8      0.119 -0.1  13.2
# 2        16.9        3.2        3.3   52.4      0.083  0.3  17.4
# 3        14.4        6.7        1.8  105.1      0.139  2.2  38.4
# 4        17.8       10.0        3.7  191.4      0.182  5.6  96.9
# 5        12.5        6.9        1.6   13.0      0.052 -3.4  -4.3
# 6        13.4        3.5        6.1   55.4      0.091  0.3  16.8
# 7         4.9        1.3        1.0    2.1      0.043 -2.3  -0.2
# 8         5.0        2.5        0.8    1.1      0.025 -3.5  -0.7
# 9         8.1        6.6        1.1   64.2      0.114 -0.7   8.6
# 10        8.6        4.5        1.0   23.2      0.113 -1.0   2.4
# 11        4.4        3.6        0.6   11.8      0.076 -2.4  -0.7
# 12       11.1        3.9        1.2   34.7      0.089 -2.0  -0.1
# 13        8.6        3.3        1.4   23.2      0.071 -2.4  -1.5
#
# [14 rows x 22 columns]

# %%
random_player = data.sample()
def save_nba_player_to_dict(player):
    return player.to_dict('list')



def announcement(test_player):
    print("With the {} pick of the {} NBA draft, which team select {}".format(test_player.get('pick_overall'),test_player.get('Year'),test_player.get('player')))
    print(test_player.get('team_id'))
        
random_player = data.sample()
test_player = save_nba_player_to_dict(random_player)
announcement(test_player)

announcement(test_player)
ans = input()
# Out:
# With the [11] pick of the [2003] NBA draft, which team select ['Mickaël Piétrus']
# ['GSW']

# %%
# Out:
# [1996]

# %%
for i in random_player:
    print(random_player[i])
# Out:
# 8    9
# Name: pick_overall, dtype: int64
# 8    1995
# Name: Year, dtype: int64
# 8    NJN
# Name: team_id, dtype: object
# 8    Ed O'Bannon
# Name: player, dtype: object
# 8    UCLA
# Name: college_name, dtype: object
# 8    2.0
# Name: seasons, dtype: float64
# 8    128.0
# Name: g, dtype: float64
# 8    2062.0
# Name: mp, dtype: float64
# 8    634.0
# Name: pts, dtype: float64
# 8    316.0
# Name: trb, dtype: float64
# 8    102.0
# Name: ast, dtype: float64
# 8    0.367
# Name: fg_pct, dtype: float64
# 8    0.222
# Name: fg3_pct, dtype: float64
# 8    0.755
# Name: ft_pct, dtype: float64
# 8    16.1
# Name: mp_per_g, dtype: float64
# 8    5.0
# Name: pts_per_g, dtype: float64
# 8    2.5
# Name: trb_per_g, dtype: float64
# 8    0.8
# Name: ast_per_g, dtype: float64
# 8    1.1
# Name: ws, dtype: float64
# 8    0.025
# Name: ws_per_48, dtype: float64
# 8   -3.5
# Name: bpm, dtype: float64
# 8   -0.7
# Name: vorp, dtype: float64
